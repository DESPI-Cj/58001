# %% [markdown]
# <a href="https://colab.research.google.com/github/DESPI-Cj/OOP-58001/blob/main/Lab_Activity_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Laboratory No.1
# "Algorithm and Flowchart"

# %%
n = 20
total_numbers = n
sum = 0
average = 0

while n>=0:
  sum+=n
  n-=1
print("sum =", sum)
average=sum/total_numbers
print("Average =", average)
# Out:
# sum = 210
# Average = 10.5

# %% [markdown]
# ![Flowchart Lab 1.png](data:image/png;base64,...)
